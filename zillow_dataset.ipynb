# %% [markdown]
# # Zillow Data

# %% [markdown]
# Import the python scientific suite

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import sklearn
import seaborn as sns
import scipy

# This is importing a "future" python version 3 print function.
from __future__ import print_function
from __future__ import division
# %matplotlib inline
sns.set()
sns.set_context('paper', font_scale = 1.5)
sns.set_style('ticks')
# Out:
# /Users/Franklin/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
file_dir = '/Volumes/1TB_BAY/zillow_sets/'

# %% [markdown]
# Read in the data and see how it is structured

# %%
d = pd.read_csv('/Volumes/1TB_BAY/zillow_sets/Neighborhood_MedianRentalPrice_1Bedroom.csv')

# %%
d.head()
# Out:
#          RegionName         City State                           Metro  \
# 0  Northeast Dallas       Dallas    TX               Dallas-Fort Worth
# 1          Paradise    Las Vegas    NV                       Las Vegas
# 2   Upper West Side     New York    NY                        New York
# 3      Sherman Oaks  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 4   Upper East Side     New York    NY                        New York
#
#     CountyName  SizeRank  2010-02  2010-03  2010-04  2010-05   ...     \
# 0       Dallas         1      NaN      NaN      NaN      NaN   ...
# 1        Clark         2      NaN      NaN      NaN      NaN   ...
# 2     New York         3     2800     2775   2747.5     2695   ...
# 3  Los Angeles         4      NaN      NaN      NaN      NaN   ...
# 4     New York         5      NaN      NaN      NaN      NaN   ...
#
#    2015-09  2015-10  2015-11  2015-12  2016-01  2016-02  2016-03  2016-04  \
# 0    850.0      795      738    789.0      765      790    864.5    807.5
# 1    750.0      700      769    789.0      805      825    849.5    825.5
# 2   3300.0     3300     3295   3250.0     3250     3250   3275.0   3255.0
# 3   1637.5     1630     1600   1629.5     1650     1620   1650.0   1647.5
# 4   2800.0     2795     2795   2795.0     2799     2800   2800.0   2800.0
#
#    2016-05  2016-06
# 0    767.5    800.0
# 1    820.0    867.5
# 2   3300.0   3240.0
# 3   1695.0   1600.0
# 4   2795.0   2725.0
#
# [5 rows x 83 columns]

# %%
dt = d.T #looks like the data will be more intelligible to us if we transpose it

dt.head(15)
# Out:
#                           0          1                2    \
# RegionName   Northeast Dallas   Paradise  Upper West Side
# City                   Dallas  Las Vegas         New York
# State                      TX         NV               NY
# Metro       Dallas-Fort Worth  Las Vegas         New York
# CountyName             Dallas      Clark         New York
# SizeRank                    1          2                3
# 2010-02                   NaN        NaN             2800
# 2010-03                   NaN        NaN             2775
# 2010-04                   NaN        NaN           2747.5
# 2010-05                   NaN        NaN             2695
# 2010-06                   NaN        NaN             2800
# 2010-07                   NaN        NaN             2800
# 2010-08                   NaN        NaN             2875
# 2010-09                   NaN        NaN             2950
# 2010-10                   NaN        NaN             2800
#
#                                        3                4              5    \
# RegionName                    Sherman Oaks  Upper East Side  East New York
# City                           Los Angeles         New York       New York
# State                                   CA               NY             NY
# Metro       Los Angeles-Long Beach-Anaheim         New York       New York
# CountyName                     Los Angeles         New York          Kings
# SizeRank                                 4                5              6
# 2010-02                                NaN              NaN            NaN
# 2010-03                                NaN              NaN            NaN
# 2010-04                                NaN              NaN            NaN
# 2010-05                                NaN              NaN            NaN
# 2010-06                                NaN              NaN            NaN
# 2010-07                                NaN              NaN            NaN
# 2010-08                                NaN              NaN            NaN
# 2010-09                                NaN              NaN            NaN
# 2010-10                                NaN              NaN            NaN
#
#                         6            7                   8    \
# RegionName  Paradise Valley  Deer Valley  Washington Heights
# City                Phoenix      Phoenix            New York
# State                    AZ           AZ                  NY
# Metro               Phoenix      Phoenix            New York
# CountyName         Maricopa     Maricopa            New York
# SizeRank                  7            8                   9
# 2010-02                 NaN          NaN                 NaN
# 2010-03                 NaN          NaN                 NaN
# 2010-04                 NaN          NaN                 NaN
# 2010-05                 NaN          NaN                 NaN
# 2010-06                 NaN          NaN                 NaN
# 2010-07                 NaN          NaN                 NaN
# 2010-08                 NaN          NaN                 NaN
# 2010-09                 NaN          NaN                 NaN
# 2010-10                 NaN          NaN                 NaN
#
#                                        9          ...          \
# RegionName                        Van Nuys        ...
# City                           Los Angeles        ...
# State                                   CA        ...
# Metro       Los Angeles-Long Beach-Anaheim        ...
# CountyName                     Los Angeles        ...
# SizeRank                                10        ...
# 2010-02                                NaN        ...
# 2010-03                                NaN        ...
# 2010-04                                NaN        ...
# 2010-05                                NaN        ...
# 2010-06                                NaN        ...
# 2010-07                                NaN        ...
# 2010-08                                NaN        ...
# 2010-09                                NaN        ...
# 2010-10                                NaN        ...
#
#                               326                   327                  328  \
# RegionName               Downtown  City Center District  Old Town Manchester
# City              West Palm Beach                Dallas             Richmond
# State                          FL                    TX                   VA
# Metro       Miami-Fort Lauderdale     Dallas-Fort Worth             Richmond
# CountyName             Palm Beach                Dallas        Richmond City
# SizeRank                      327                   328                  329
# 2010-02                       NaN                   NaN                  NaN
# 2010-03                       NaN                   NaN                  NaN
# 2010-04                       NaN                   NaN                  NaN
# 2010-05                       NaN                   NaN                  NaN
# 2010-06                       NaN                   NaN                  NaN
# 2010-07                       NaN                   NaN                  NaN
# 2010-08                       NaN                   NaN                  NaN
# 2010-09                       NaN                   NaN                  NaN
# 2010-10                       NaN                   NaN                  NaN
#
#                        329           330           331            332  \
# RegionName  Central Office   Spruce Hill  Society Hill  Spring Garden
# City              Richmond  Philadelphia  Philadelphia   Philadelphia
# State                   VA            PA            PA             PA
# Metro             Richmond  Philadelphia  Philadelphia   Philadelphia
# CountyName   Richmond City  Philadelphia  Philadelphia   Philadelphia
# SizeRank               330           331           331            331
# 2010-02                NaN           NaN           NaN            NaN
# 2010-03                NaN           NaN           NaN            NaN
# 2010-04                NaN           NaN           NaN            NaN
# 2010-05                NaN           NaN           NaN            NaN
# 2010-06                NaN           NaN           NaN            NaN
# 2010-07                NaN           NaN           NaN            NaN
# 2010-08                NaN           NaN           NaN            NaN
# 2010-09                NaN           NaN           NaN            NaN
# 2010-10                NaN           NaN           NaN            NaN
#
#                      333           334                335
# RegionName  Logan Square   Rittenhouse  Washington Square
# City        Philadelphia  Philadelphia       Philadelphia
# State                 PA            PA                 PA
# Metro       Philadelphia  Philadelphia       Philadelphia
# CountyName  Philadelphia  Philadelphia       Philadelphia
# SizeRank             331           331                331
# 2010-02              NaN           NaN                NaN
# 2010-03              NaN           NaN                NaN
# 2010-04              NaN           NaN                NaN
# 2010-05              NaN           NaN                NaN
# 2010-06              NaN           NaN                NaN
# 2010-07              NaN           NaN                NaN
# 2010-08              NaN           NaN                NaN
# 2010-09              NaN           NaN                NaN
# 2010-10              NaN           NaN                NaN
#
# [15 rows x 336 columns]

# %%
names = dt[:6] #separate out the string data from the timeseries
ts = dt[6:] #just the timeseries

tnames = names.T #create an un-transposed names copy. This will be useful later.

# %% [markdown]
# Ok, so it looks like that the files track rental prices for a given Neighborhood, in a city, which is a in a state. There is also a Metro grouping. Then, the median rental price (by month) is in the next 77 columns. Looks like there is about 5 years of data. So, we need to find a way to extract the price timeseries for each region.
#
# The first step is to extract the time coordinate from the column name. I will assume that each datapoint is for the middle of each month. We see a column that is named 2010-02, meaning Feb 2010. I'll set the x-value for this point to be Feb 15th, 2010.
#
# We'll need some time machinery for this next part:

# %%
import datetime
from astropy.time import Time, TimeDelta

# %%
t_start = Time(datetime.datetime(2010,2,15)) #create the start time
t_int = TimeDelta(30.4166, format = 'jd') #time interval between a month

# %%
t_abcissa = [] #create empty list to hold time time objects

for i in range(77):
    t_abcissa.append(t_start + i*t_int) #add a month for 77 months
    
t_column = []

for t in t_abcissa: #for each time
    t_column.append(t.jd) #convert the time to jd and add it to a new column

# %%
#add the column back into that dataframe
ts.loc[:,'time'] = pd.Series(t_column, index = ts.index)

# %% [markdown]
# Now we have the machinery to plot the pricing history of a neighborhood as a function of time. The time unit is Julian Days, which is what astronomers use as a date coordinate. The important part is that the units are just days, so that when we derive the pricing trend for each neighborhood, we will get a trend in (dollars/day), which is easy to wrap our brains around.

# %%
plt.title(names[1]['RegionName'], y = 1.03) #make a title that is the neighborhood price history
plt.scatter(ts['time'],ts[1]) #scatter the pricing trends
plt.xlabel('Julian Date')
plt.ylabel('Median Listing Price ($)')
sns.despine() # make the plot pretty

# %% [markdown]
# Just to see what we are doing here, let's look at all the neighborhoods pricing history on one plot

# %%
for i in range(len(ts.T) - 1):
    plt.scatter(ts['time'],ts[i], lw = 0, s = 2, alpha = 0.5) #scatter the pricing trends
    
plt.xlabel('Julian Date')
plt.ylabel('Median Listing Price ($)')
sns.despine() # make the plot pretty

# %% [markdown]
# The boundaries for all of the neighborhoods can be found here: http://www.zillow.com/howto/api/neighborhood-boundaries.htm
#
# Let's compute some stats for each neighborhood. Stuff we would be interested in includes:
#
# 1) Median Price
# 2) Price Linear Trend
# 3) Price Linearity Value

# %%
import statsmodels.formula.api as smf #import some statsmodels stuff

# %%
mean_price = [] #mean price
lin_trend = [] #linear slope in dollars per day

#len(tnames) - 1

for i in range(1):
    mean_price.append(np.mean(ts[i]))
    
    #create a clean little DataFrame for fitting our line with statsmodels.
    
    fit_df = ts[[i,'time']]
    f = fit_df.rename(columns = {i: 'price'}).apply(pd.to_numeric).dropna() #clean up the fit by dropping the missing values
    
    lin = smf.OLS(f['price'], f['time']).fit()
    
    
    #lin_trend.append()

# %%
sns.distplot(mean_price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-935f234689bb> in <module>()
# ----> 1 sns.distplot(mean_price)
#
# /Users/Franklin/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     207     if hist:
#     208         if bins is None:
# --> 209             bins = min(_freedman_diaconis_bins(a), 50)
#     210         hist_kws.setdefault("alpha", 0.4)
#     211         hist_kws.setdefault("normed", norm_hist)
#
# /Users/Franklin/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in _freedman_diaconis_bins(a)
#      28     # From http://stats.stackexchange.com/questions/798/
#      29     a = np.asarray(a)
# ---> 30     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      31     # fall back to sqrt(a) bins if iqr is 0
#      32     if h == 0:
#
# TypeError: len() of unsized object
